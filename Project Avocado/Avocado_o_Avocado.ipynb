# %%
import pandas as pd
import numpy as np
pd.set_option('max_columns', 120)
pd.set_option('max_colwidth', 5000)
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
plt.rcParams['figure.figsize'] = (12,8)

# %%
avocado_prices_1 = pd.read_csv('avocado.csv', skiprows=1, low_memory=False)
avocado_count = len(avocado_prices_1) 
avocado_prices_1 = avocado_prices_1.dropna(thresh=avocado_count,axis=1) 
avocado_prices_1 = avocado_prices_1.drop(['0.0'],axis=1)

# %%
avocado_prices_1.head(20)
# Out:
#      0  2015-12-27  1.33   64236.62  1036.74   54454.85   48.16   8696.87  \
# 0    1  2015-12-20  1.35   54876.98   674.28   44638.81   58.33   9505.56
# 1    2  2015-12-13  0.93  118220.22   794.70  109149.67  130.50   8145.35
# 2    3  2015-12-06  1.08   78992.15  1132.00   71976.41   72.58   5811.16
# 3    4  2015-11-29  1.28   51039.60   941.48   43838.39   75.78   6183.95
# 4    5  2015-11-22  1.26   55979.78  1184.27   48067.99   43.61   6683.91
# 5    6  2015-11-15  0.99   83453.76  1368.92   73672.72   93.26   8318.86
# 6    7  2015-11-08  0.98  109428.33   703.75  101815.36   80.00   6829.22
# 7    8  2015-11-01  1.02   99811.42  1022.15   87315.57   85.34  11388.36
# 8    9  2015-10-25  1.07   74338.76   842.40   64757.44  113.00   8625.92
# 9   10  2015-10-18  1.12   84843.44   924.86   75595.85  117.07   8205.66
# 10  11  2015-10-11  1.28   64489.17  1582.03   52677.92  105.32  10123.90
# 11  12  2015-10-04  1.31   61007.10  2268.32   49880.67  101.36   8756.75
# ...

# %%
avocado_prices_1.shape
# Out:
# (18248, 13)

# %%
df = pd.read_csv('avocado.csv')
df.head()
# Out:
#    Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0           0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1           1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2           2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3           3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4           4  2015-11-29          1.28      51039.60   941.48   43838.39
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0   48.16     8696.87     8603.62       93.25          0.0  conventional
# 1   58.33     9505.56     9408.07       97.49          0.0  conventional
# 2  130.50     8145.35     8042.21      103.14          0.0  conventional
# 3   72.58     5811.16     5677.40      133.76          0.0  conventional
# 4   75.78     6183.95     5986.26      197.69          0.0  conventional
#
#    year  region
# 0  2015  Albany
# 1  2015  Albany
# 2  2015  Albany
# ...

# %%
to_drop = ['XLarge Bags',
           'Unnamed: 0']

df.drop(to_drop, inplace=True, axis=1)

# %%
df.head()
# Out:
#          Date  AveragePrice  Total Volume     4046       4225    4770  \
# 0  2015-12-27          1.33      64236.62  1036.74   54454.85   48.16
# 1  2015-12-20          1.35      54876.98   674.28   44638.81   58.33
# 2  2015-12-13          0.93     118220.22   794.70  109149.67  130.50
# 3  2015-12-06          1.08      78992.15  1132.00   71976.41   72.58
# 4  2015-11-29          1.28      51039.60   941.48   43838.39   75.78
#
#    Total Bags  Small Bags  Large Bags          type  year  region
# 0     8696.87     8603.62       93.25  conventional  2015  Albany
# 1     9505.56     9408.07       97.49  conventional  2015  Albany
# 2     8145.35     8042.21      103.14  conventional  2015  Albany
# 3     5811.16     5677.40      133.76  conventional  2015  Albany
# 4     6183.95     5986.26      197.69  conventional  2015  Albany

# %%
df['Date'].is_unique
# Out:
# False

# %%
df.iloc[0]
# Out:
# Date              2015-12-27
# AveragePrice            1.33
# Total Volume         64236.6
# 4046                 1036.74
# 4225                 54454.8
# 4770                   48.16
# Total Bags           8696.87
# Small Bags           8603.62
# Large Bags             93.25
# type            conventional
# year                    2015
# region                Albany
# Name: 0, dtype: object

# %%
df.get_dtype_counts()
# Out:
# object     3
# float64    8
# int64      1
# dtype: int64

# %%
from jsonify import convert
from flask import jsonify

# %%
df.to_json('Avocado_o_Avocado.json', orient='records', lines=True)
